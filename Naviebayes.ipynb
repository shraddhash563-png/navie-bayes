# %% [markdown]
# ****Navie Bayes****

# %% [markdown]
# ###Navie Bayes
#
# > Predicts  the classes based on the probabilistic value..
#
# > bayes theorem->conditional probability..
#
# >navie->i/p features are independent..
#
# <img src"![WhatsApp Image 2026-09-21 at 10.39.35 AM.jpeg](data:image/jpeg;base64,...)"

# %%
import pandas as pd
import numpy as np

# %%
columns =     ["fLength","fWidth","fSize","fConc","fConc1","fAsym","fM3Long","fM3Trans","fAlpha","fDist","class"]

# %%
columns
# Out:
# ['fLength',
#  'fWidth',
#  'fSize',
#  'fConc',
#  'fConc1',
#  'fAsym',
#  'fM3Long',
#  'fM3Trans',
#  'fAlpha',
#  'fDist',
#  'class']

# %%
len(columns)
# Out:
# 11

# %%
df = pd.read_csv("/content/magic04.data",names=columns)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df = pd.read_csv("/content/magic04.data",names=columns)
df.tail()
# Out:
#         fLength   fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 19015   21.3846  10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452   6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455  47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135  76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814  53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist class
# 19015    2.8766   2.4229  106.8258     h
# 19016   -2.9632  86.7975  247.4560     h
# 19017   -9.4662  30.2987  256.5166     h
# 19018  -63.8389  84.6874  408.3166     h
# 19019   31.4755  52.7310  272.3174     h

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   19020 non-null  float64
#  1   fWidth    19020 non-null  float64
#  2   fSize     19020 non-null  float64
#  3   fConc     19020 non-null  float64
#  4   fConc1    19020 non-null  float64
#  5   fAsym     19020 non-null  float64
#  6   fM3Long   19020 non-null  float64
#  7   fM3Trans  19020 non-null  float64
#  8   fAlpha    19020 non-null  float64
#  9   fDist     19020 non-null  float64
#  10  class     19020 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (19020, 11)

# %%
df.describe()
# Out:
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      53.250154     22.180966      2.825017      0.380327      0.214657
# std       42.364855     18.346056      0.472599      0.182813      0.110511
# min        4.283500      0.000000      1.941300      0.013100      0.000300
# 25%       24.336000     11.863800      2.477100      0.235800      0.128475
# 50%       37.147700     17.139900      2.739600      0.354150      0.196500
# 75%       70.122175     24.739475      3.101600      0.503700      0.285225
# max      334.177000    256.382000      5.323300      0.893000      0.675200
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      -4.331745     10.545545      0.249726     27.645707    193.818026
# ...

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df['class']
# Out:
# 0        g
# 1        g
# 2        g
# 3        g
# 4        g
#         ..
# 19015    h
# 19016    h
# 19017    h
# 19018    h
# 19019    h
# Name: class, Length: 19020, dtype: object

# %%
#### g-1 h-0
df['class'] = (df['class'] == 'g').astype(int)

# %%
df['class']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 19015    0
# 19016    0
# 19017    0
# 19018    0
# 19019    0
# Name: class, Length: 19020, dtype: int64

# %%
x= df[df.columns[:--1]].values

# %%
### check number of gamma and number hadron in class

import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])
# Out:
# /usr/local/lib/python3.13/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
def scale_dataset(dataframe, oversample=False):
  X = dataframe[dataframe.columns[:-1]].values#input
  y = dataframe[dataframe.columns[-1]].values#output

  scaler = StandardScaler()
  X = scaler.fit_transform(X) # its scaled input

  if oversample:
    ros = RandomOverSampler()
    X, y = ros.fit_resample(X, y)

  data = np.hstack((X, np.reshape(y, (-1, 1))))

  return data, X, y

# %%
train
# Out:
#         fLength   fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 11843   35.1938  15.1926  2.5159  0.3262  0.1753   24.3540   21.1519
# 18162  139.7989  90.8769  3.6631  0.1837  0.1067 -115.1394 -128.0299
# 2247    18.3861  10.3691  2.3541  0.5752  0.3341  -22.1874  -11.0277
# 15764   25.7563  19.0266  2.6196  0.3842  0.1933    8.2673   24.5412
# 18474   90.0481  13.9973  3.1377  0.2466  0.1413 -101.4084   35.1786
# ...         ...      ...     ...     ...     ...       ...       ...
# 6070    25.6886   7.9251  2.3711  0.6723  0.4021   14.1407   19.4220
# 7853    22.3722   9.5392  2.2455  0.6023  0.3153    1.3431  -13.8852
# 11291   93.3800  31.0536  3.3826  0.1918  0.0963   49.7334   92.3385
# 10822   65.8344  24.3085  3.3792  0.1904  0.0979    9.4571   55.7010
# 9982    15.8049  11.8389  2.4518  0.6254  0.3375   -1.9127    5.0444
#
#        fM3Trans   fAlpha     fDist  class
# 11843   13.5179   7.1943  217.9030      1
# 18162  -62.1186  53.7335  407.4667      0
# ...

# %% [markdown]
# > Done with data preparation (standardization and balancing)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.metrics import classification_report

# %%
nb = GaussianNB()

# %%
# train the model
nb.fit(train[train.columns[:-1]], train[train.columns[-1]])
# Out:
# GaussianNB()

# %%
nb.predict(train[train.columns[:-1]])
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %%
pd.DataFrame(nb.predict(train[train.columns[:-1]])).value_counts()
# Out:
# 0
# 1    9307
# 0    2105
# Name: count, dtype: int64

# %%
# evaluating model
print(classification_report(train[train.columns[-1]], nb.predict(train[train.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.38      0.49      3945
#            1       0.74      0.92      0.82      7467
#
#     accuracy                           0.73     11412
#    macro avg       0.72      0.65      0.66     11412
# weighted avg       0.73      0.73      0.71     11412

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(train[train.columns[:-1]], train[train.columns[-1]])
kpedict = knn.predict(train[train.columns[:-1]])

# %%
print(classification_report(train[train.columns[-1]], kpedict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.68      0.77      3945
#            1       0.85      0.95      0.90      7467
#
#     accuracy                           0.86     11412
#    macro avg       0.86      0.81      0.83     11412
# weighted avg       0.86      0.86      0.85     11412

# %% [markdown]
# >KNN has 81% of accuracy
